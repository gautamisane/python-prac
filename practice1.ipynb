# %%
#output and printing
print('hello world')
# Out:
# hello world

# %%
x = 5
y = "John"
print(x,y)
# Out:
# 5 John

# %%
x = "four"
print(type(x))
print( x + "five")
# Out:
# <class 'str'>
# fourfive

# %%
x = "Python is "
y = "awesome"
z =  x + y
print(z)
# Out:
# Python is awesome

# %%
#global variable
x = "awesome"

def myfunc():
  print("python is " + x)

myfunc()
myfunc()
myfunc()
# Out:
# python is awesome
# python is awesome
# python is awesome

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()  #local variable will be printed

print("Python is " + x) 

myfunc() #local again printed as in function local is declared
# Out:
# Python is fantastic
# Python is awesome
# Python is fantastic

# %%
a = "Hello"
print(a[1])
# Out:
# e

# %%
for x in "hello":                       #loop through string 
  print(x)
# Out:
# h
# e
# l
# l
# o

# %%
x = "hello girl"
print(len(x))
print("hello" in x)
# Out:
# 10
# True

# %%
x = "hello girl"
if "hello" in x:
  print("Yes present")                        #if hello word/phrase present in x string then print..

# %%
b = "hello"
print(b[2:5])   #5 not included
print(b[:5])    #starts from 0
print(b[1:])    #goes on till last

# %%
#string methods  -- create substrings using separator
'This is Gautami'.split()
# Out:
# ['This', 'is', 'Gautami']

# %%
#count number of words
sentence = "This is a class"
words = sentence.split()
len1 = len(words)
print(len1)
# Out:
# 4

# %%
#list --> are ordered, changeable and allow duplicate values
this = ["apple", "banana", "mango"]
print(this)
print(type(this))
print(this[0])#accessing list items using indexing
print(this[:2]) #range of accessing and printing

# %%
#python input
user = input("enter a number")   #user input stored in user variable
print('the number is' + user)
# Out:
# enter a number 6
# the number is 6

# %%
#add two numbers
x = 5
y = 9
print(x + y)
# Out:
# 14

# %%
x = input("ENTER NUMBER 1 ")
y = input("ENTER NUMBER 2 ")
z = int(x) + int(y)
print(z)
# Out:
# ENTER NUMBER 1 3
# ENTER NUMBER 2 4
# 7
